# %% [markdown]
# # Test Emulated Performance
#
# Test the `get_emulated` method and calculate Cartesian performance across all trajectories.

# %%
# !pip install dtw-python
# Out:
# Requirement already satisfied: dtw-python in /home/arash/anaconda3/envs/dnfc/lib/python3.9/site-packages (1.7.4)
# Requirement already satisfied: numpy>=2.0 in /home/arash/anaconda3/envs/dnfc/lib/python3.9/site-packages (from dtw-python) (2.0.2)
# Requirement already satisfied: scipy in /home/arash/anaconda3/envs/dnfc/lib/python3.9/site-packages (from dtw-python) (1.13.1)

# %%
from testers import Tester

# %%
t = Tester()
# Out:
# Tester loaded dataset with shape: (11, 299, 35)
# from this path /home/arash/research/dnfc-torobo/feedback_controller/fbc/neural_network/data/torobo/trajs:72_blocks:3_triangle_v_scarce/test_interp_0.85.npy
# No data file named /home/erhan/catkin_ws/src/erhtor_work/tormain/Resources/larm60.txt
# bodypart structure for larm is constructed.
# No data file named /home/erhan/catkin_ws/src/erhtor_work/tormain/Resources/rarm60.txt
# bodypart structure for rarm is constructed.
# bodypart structure for head is constructed.

# %%
t.load_model(train_no=0, epoch_no=10000, use_custom_loss=False, model_complexity='high')
# Out:
# ***
# Loaded model weights from /home/arash/research/dnfc-torobo/feedback_controller/fbc/neural_network/weights/trajs:72_blocks:3_triangle_v_scarce|interp_0.85|mse_los|tar_cart|robo_enc_eef_N=4_plus_joints_noise=0.1_only6|40.739K_params/train_no_0/fbc_10000.pth

# %%
# Test Cartesian performance and DTW across all trajectories
score, avg_dtw, avg_dtw_norm = t.calculate_cartesian_perform_with_dtw(use_baseline=False)
print(f'Cartesian performance: {score}%')
print(f'Average DTW distance: {avg_dtw}')
print(f'Average normalized DTW distance: {avg_dtw_norm}')
# Out:
# Importing the dtw module. When using in academic works please cite:
#   T. Giorgino. Computing and Visualizing Dynamic Time Warping Alignments in R: The dtw Package.
#   J. Stat. Soft., doi:10.18637/jss.v031.i07.
#
# Cartesian performance: 0.4318181818181818%
# Average DTW distance: 61.70032374460531
# Average normalized DTW distance: 0.10317779890402229

# %%
# loop
epoch_no = 10000
all_scores = []
all_dtws = []
all_dtw_norms = []
for i in range(3):
    t.load_model(train_no=i, epoch_no=epoch_no, use_custom_loss=False, model_complexity='high')
    score, avg_dtw, avg_dtw_norm = t.calculate_cartesian_perform_with_dtw(use_baseline=False)
    all_scores.append(score)
    all_dtws.append(avg_dtw)
    all_dtw_norms.append(avg_dtw_norm)
    print(f'Train {i}: score={score:.4f}, DTW={avg_dtw:.4f}, DTW_norm={avg_dtw_norm:.4f}')
# Out:
# ***
# Loaded model weights from /home/arash/research/dnfc-torobo/feedback_controller/fbc/neural_network/weights/trajs:72_blocks:3_triangle_v_scarce|interp_0.85|mse_los|tar_cart|robo_enc_eef_N=4_plus_joints_noise=0.1_only6|40.739K_params/train_no_0/fbc_10000.pth
# Train 0: score=0.4318, DTW=61.7003, DTW_norm=0.1032
# ***
# Loaded model weights from /home/arash/research/dnfc-torobo/feedback_controller/fbc/neural_network/weights/trajs:72_blocks:3_triangle_v_scarce|interp_0.85|mse_los|tar_cart|robo_enc_eef_N=4_plus_joints_noise=0.1_only6|40.739K_params/train_no_1/fbc_10000.pth
# Train 1: score=0.2273, DTW=113.8223, DTW_norm=0.1903
# ***
# Loaded model weights from /home/arash/research/dnfc-torobo/feedback_controller/fbc/neural_network/weights/trajs:72_blocks:3_triangle_v_scarce|interp_0.85|mse_los|tar_cart|robo_enc_eef_N=4_plus_joints_noise=0.1_only6|40.739K_params/train_no_2/fbc_10000.pth
# Train 2: score=0.1364, DTW=100.6765, DTW_norm=0.1684

# %%
# Cartesian performance: 72.7%

# In train set, with decreasing epoch_no, the performance decreases as well. 

# In test set, maybe.

# %%
# With joints only, around 30%.
