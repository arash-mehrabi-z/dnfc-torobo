# %% [markdown]
# # Test Emulated Performance
#
# Test the `get_emulated` method and calculate Cartesian performance across all trajectories.

# %%
from testers import Tester

# %%
t = Tester()
# Out:
# Tester loaded dataset with shape: (11, 299, 35)
# from this path /home/arash/catkin_ws/src/feedback_controller/fbc/neural_network/data/torobo/trajs:72_blocks:3_triangle_v_scarce/test_interp_0.85.npy
# No data file named /home/erhan/catkin_ws/src/erhtor_work/tormain/Resources/larm60.txt
# bodypart structure for larm is constructed.
# No data file named /home/erhan/catkin_ws/src/erhtor_work/tormain/Resources/rarm60.txt
# bodypart structure for rarm is constructed.
# bodypart structure for head is constructed.

# %%
t.load_model(train_no=0, epoch_no=6200, use_custom_loss=False, model_complexity='XXhigh')
# Out:
# ***
# Loaded model weights from /home/arash/catkin_ws/src/feedback_controller/fbc/neural_network/weights/trajs:72_blocks:3_triangle_v_scarce|interp_0.85|mse_los|tar_cart|rob_enc_noise3|123.939K_params/train_no_0/fbc_6200.pth

# %%
# Test Cartesian performance across all trajectories
# Returns the fraction of milestones reached (4 milestones per trajectory)
perf = t.calculate_cartesian_perform(use_baseline=False)
print(f'Cartesian performance: {perf*100:.1f}%')
# Out:
# Cartesian performance: 45.5%
